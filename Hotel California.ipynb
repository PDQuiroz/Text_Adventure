# %% [markdown]
#  Please install package before running game

# %%
# !pip install pyfiglet

# %% [markdown]
# # Escape Hotel California

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Oct 12 18:34:06 2020

Docstring

                    --- Escape The Hotel California ---
                    
                           ...Pablo Quiroz...

    Welcome to a game inspired by the classic rock song 'Hotel California' by the
    Eagles. The objective of the game is to escape this strange hotel. There is 
    more than one way out, and more than one way to truly win the game. Since
    there are many different endings I have added a few things to streamline 
    your experience, please only try them AFTER the first user intros. 

   

    - You may use ["exit", "ex", "get out", "leave"] at any time* to leave the game
    - You may use ["again", "restart", "repeat"] at any time* to restart the game
    - Please use only "1" or "one" when selecting an option
        e.g
           for 1 <- use '1' or 'one' or 'uno'
           for 2 <- use '2' or 'two' or 'dos'
           for 3 <- use '3' or 'three' or 'tres'
    

     *Considering "at any time" only when a text input is required
     
     
    Enjoy!




"""
#Importing packages for date, random and be able to "turn on the radio"
import datetime
import webbrowser
import random
import time
import pyfiglet

from colorama import Fore, Back, Style

day = datetime.datetime.now().strftime("%A")
hour = datetime.datetime.now().strftime("%H:%M")

#defining various lists for in functions / adding replayability
one = ["one", "1", "uno"]
two = ["two", "2", "dos"]
three = ["three", "thre", "tres", "3"]

exit = ["exit", "ex", "get out", "leave"]
again = ["again", "restart", "repeat"]

yes = ["yes", "y", "yea", "yeah", "si"]
no = ["no", "n", "nope", "never", "jamas"]


#Random comments spread throughout the game
easter = ["Snitches get Stitches", "You should use less social media", "Never pet an unkwown dog without permission"]

clues= [ "We don't need doorknobs in a place like this", "Bananas are a great source of pottasium", 
        "A lighter a day keeps the devils away", "Always indent to avoid invalid syntax", "Sleep at least 6-8 hours a day",
        "Drink two liters of water daily!"]

radio = ['https://www.youtube.com/watch?v=gLS0kGhIHjs&list=PL83E8EC6583423A0F&ab_channel=TarantinoFM',
        'https://www.youtube.com/watch?v=dEnGjhDFtKY&list=PLDisKgcnAC4Tn2kjbXBPiXDu5lVCffkLr&ab_channel=OriginalSoundtrack',
        'https://www.youtube.com/watch?v=4-43lLKaqBQ&ab_channel=TheAnimalsTributeChannel',
        'https://www.youtube.com/watch?v=5oWyMakvQew&ab_channel=FleetwoodMac-Topic',
        'https://www.youtube.com/watch?v=zzICMIu5zFY&ab_channel=MartyRobbins-Topic']

moto = ['Say bazinga while you press any key to Continue' , 'Remember to press any key to continue', 'Drink water and then press any key to continue',
        'Make sure you sleep at least 6 hours a day and press any key to continue']

#variables used for gambling with the devil
dice = [1,2,3,4,5,6]
max_gamble = 16



#Using both colorama package and pyfiglet to add a nice font / color intro to the game
escape = pyfiglet.figlet_format("      Escape the", font = "bulbhead" ) 
hotel = pyfiglet.figlet_format(" Hotel ", font = "isometric1" ) 
california = pyfiglet.figlet_format("      California", font = "bulbhead" ) 

print( Fore.RED + escape ) 
print( Back.BLACK + Fore.WHITE + hotel ) 
#resetting style so that the black background ->Back.BLACK is not carried over to the next
print( Style.RESET_ALL )
print( Fore.RED + california ) 

#resetting the style of it all
print( Style.RESET_ALL )







#name input for user
#using casefold to lowercase even special characters.
#adding a capitalize to keep the name with a capital letter at start

name = input(prompt = f"""
                             {'~' * 50}
             
                                 Hi, before we check you in
                                 we must know. What is your name?
                             
                             {'~' * 50}
                             \n""").casefold().capitalize()#casefold leaves in lower even special characters and we capitalize the first letter of the name

#user chooses a car model
car = input(prompt = f"""
                             {'~' * 50}
             
                                 Nice to meet you {name}, what
                                 is your car and car model so we 
                                 can register it in the system? 
                             
                             {'~' * 50}
                             \n""")



#user chooses to have or not have music with webbrowser package.
def intro():
    music = input(prompt = f"""
                   
                            {'~' * 50}
                                               
                                Welcome to the Hotel California {name}
                                We hope you enjoy your stay!
                                
                            
                            {'~' * 50}
                            
                            Would you like some music for your adventure?
                            
                                    < Yes / No >
             
""" ).casefold() 
    if music in yes:
        #using web browser + random choice to open a random youtube link from radio list
        webbrowser.open(random.choice(radio))
                       
    elif music in no:
        print("Have it your way")
    
    elif music in exit:
        see_ya()
    elif music in again:
        print("You still haven't begun the adventure to be able to restart it!")
        intro()
        
    else:
        print("I didn't quite catch that, please try again")
        intro()
        
                   

    part_1()
    
    
#part_1 initiates game / intro is for user inputs

#some branches share stages with others hence, the apparent excess of functions
#to be able to "loop" around the stage

def part_1():
    
    x = 0
    
    #while loop to simulate ringing
    while x < 5:
        time.sleep(0.8)
        print("\n ring... \n")
        x += 1
    
    #random inputs based on lists to keep the intro "fresh" and give the user
    #some clues...
    input(prompt = f"""

Hey {name}, this is reception calling to wake you up. 
It's already {hour} of a beautiful {day} and the ball at the courtyard will begin soon. 

Remember! {random.choice(clues)}


Waking up you remember that you were chasing a white rabbit, 
damn, how long ago was that?

Is this what a hangover feels like in your 27's? Talk about the 27 club hahaha...

I don't remember checking into a Hotel room. Much less falling asleep.




< {random.choice(moto)} >
""")
    #passes to next choice
    choice_1()
                
    





    #First set of choices which kick out the whole adventure
    #Each choice creates a new branch of choices (except check watch)
def choice_1():
    ans = input(prompt = """
What to do, what to do
                
1. Check your pockets
2. Go outside for a walk
3. Check the time 

""").casefold()
    #using 'in' to create lists of alternatives for each choice
    if ans in one:
        print("""
You check your pockets only to find a hotel card and some purple pills.
The cards says 1250 Hotel California. Huh, just like the song by the eagles...

You see a suitcase lying by the bedframe and a lighter on the nightstand. 

""")
        checking()

    elif ans in two:
        print(f"""
You head for the door and realize there is no doorknob. You look through the 
peep hole only to see an old vintage rug covering the eternal hallway of what
you think is a hotel. It must be since they called you from reception.

There is a strong light coming at the end of it. "Led lights
really are powerful..." you think to yourself

Have you been abducted? You go check the window only to find an empty parking
lot in the dessert except for a {car}. 
""")
        out_of_door()

    elif ans in three:
        print(f"You check your watch, it's {hour}. It feels like something is missing.")
        choice_1_1()

    elif ans in exit:
        see_ya()
        
    elif ans in again:
        fail()
        
    else:
        print("I didn't get that")
        choice_1()
        
        
   #same as the last function except without the check watch option.
   #encourages exploration of alternatives
def choice_1_1():
    ans = input(prompt = """
Only two things left to do
                
1. Check your pockets
2. Go outside for a walk


""").lower().strip()
                
    if ans in one:
      print("""
You check your pockets only to find a hotel card and some purple pills.
The cards says 1250 Hotel California. Huh, just like the song by the eagles...

You see a suitcase lying by the bedframe and a lighter on the nightstand. 

"""); checking()
                  


    elif ans in two:
        print(f"""
You head for the door and realize there is no doorknob. You look through the 
peep hole only to see an old vintage rug covering the eternal hallway of what
you think is a hotel. There is a strong light coming at the end of it. Led lights
really are powerful...

Have you been abducted? You go check for the window to find an empty parking
lot in the dessert except for a {car}. 
""")
        
        out_of_door()

    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
        #returns to the same function if it doesn't work
    else:
        print("I didn't catch that")
        choice_1_1()


def checking():
    input(prompt = """ 
< Press Any Key to Continue >
""")

    ans = input (prompt = """
1. Check the Suitcase
2. Take the pills
3. Grab the lighter
""").lower()

    if ans in one:
        print(f"""
You find your lucky rabbit paw key in the suitcase, apparently
you have a {car}, nice ride.

""")
        suitcase()
        
    elif ans in two:
        print("""
You can't grab the pills, they slip right through your hand...
What the actual f***?


""")
        pills()
        #different ans will direct the user to new, pre defined rooms
    elif ans in three:
        lighter()
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
            print("What? Please try again")
            checking()
            
            
            
def lighter():
    print("""
You grab the lighter, it's your trusty zippo. The one you
have been using to heat up spoons...
          
You suddenly feel an urge to escape, to get out of this place,
this god forsaken place. This hotel does not let you think properly,
it's all so weird, so strange, but so natural at the same time.

Are you going mad?
          
You feel the need for action, get out of here your head screams at you.
Burn it all down

""")
    
    input(prompt = "Press Any Key to Continue")
    
    ans = input(prompt = """
                
 1. You jump out the window without looking back
 2. You rush out the door
 3. You burn the room
 """).lower()
 
    if ans in one:
         parking_lot_lighter()
    elif ans in two:
        door_travel_lighter_1()
    elif ans in three:
        print (""" 
You set the room on fire. Starting by the curtains and 
moving onto the bed and the carpet. Even though the flames are 
raging you feel no heat. You touch the fire but feel nothing.
               
You turn around to see your life long partner looking at you
               
"You shouldn't have come here"
               
You remember your past life, and are ashamed of how 
you didn't take it seriously, how you didn't rush to the
ER when it was needed most...""")
               
               
        input(prompt = "< Press Any Key to Stay in Purgatory >")
        fail()
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
           print("I didn't quite catch that, please try again")
           lighter()
#alternative to parking lot when user does have a lighter. 
def parking_lot_lighter():
    print(f""" 
You jump out the window. As you are falling you see your {car} park outside,
maybe that is your way out...You fall sideways on the concrete but nothing happens to you.
          
You hear music coming from the Hotel and there is a mysterious man standing 
next to an unlit candlestick. 
          
""")
    input(prompt = "< Press Any Key to Continue >")
    
    ans = input(prompt = """
1. Try to open your car
2. Head in to hotel
3. Light the candlestick
""").lower()
          
    if ans in one:
             print("""
You try to open the car but it is locked. As you turn around to head
to the hotel, the man in the hat, and the rest of the guests have approached you.
                    
"You can stay as long as you like, but you cannot leave" says the man in the hat. 
                    
Suddenly it is dusk, the last rays of sunset have fleed the horizon. You feel
your body getting lighter and lighter, you close your eyes and forget you 
were ever here.
                    
                    """)
             input(prompt = "< Press Any Key to Stay in Purgatory >")
             fail()
    elif ans in two:
        print(f""" 
You head into the hotel following the music, but before you
can enter the courtyard the man in the hat stops you.
              
"Welcome {name}, I don't believe we have met. I am the owner of this
fine establishment. You can stay for as long as you want but 
you cannot leave"
              
You turn around to see a familiar face, your life long partner. 
You both share a smile for a moment.
              
"You shouldn't have come here, not like this, you had to get out"
              """)
        input(prompt = "< Press any Key to Enter Purgatory >")
        fail()
    elif ans in three:
        candlestick()
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
        print("I didn't quite catch that")
        parking_lot_lighter()
        
          
def door_travel_lighter_1():
    print("""
You rush out the door but before you can open it, you realize that there is no doorknob.
You try to hit the door but your fist falls right through it.
          
Are you a ghost?
          
You cross the door and see a light at the end of the hallway, with a sign pointing
to the reception. You also hear music coming from below.""")
          
    door_travel_lighter2()
          
def door_travel_lighter2():
    ans = input(prompt="""

1. Head back in the room and jump out the window
2. Go downstairs
3. Go to the lobby to file a complaint due to supernatural causes
""")
                
    if ans in one:
            parking_lot_lighter()
    elif ans in two:
        print("You make your way downstairs to the courtyard to find all of the guests dancing and drinking")

        courtyard_lighter()
    #game easter egg
    elif ans in three:
        print("""
You make your way to the lobby to file a complaint about what
is going on here. Truth be told, it seems to be an awful lot
like a poorly programmed adventure game... Consider this an Easter Egg
or a life long lesson.""")
              
        input(prompt = """Press whatever you want for an easter egg or life long advice""")
       #Random easter eggs based on a list
        print(f"""

{random.choice(easter)} {name}
              
You die under strange circumstances, btw this is the purgatory
              
              """)
        fail()
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
        print("I didn't catch that")
        door_travel_lighter2()
        
def dance():
    print("""
               
You head to the dance and approach the person that looks familiar.

They smile at you, like two long lost friends finding each other.
               
"Some dance to remember others dance to forget." 
              
You dance until you remember, you remember you died a few
days ago, you remember life has been tough on you
since your partner passed away. 
              
You see them looking at you with tears in their eyes.

You smile thinking you would never see them again, but they cry. 
              
"This is not were I wanted to find you again, you had to leave...
but it's beautiful to see you again." 
              
""")
              
    input(prompt = "< Press Any Key to Drink Margaritas and Stay in Purgatory Dancing >")
    fail()
            
    
def escape_parking():
     print ("""
You head for the parking lot. As soon as you take a step forward
the music stops, everybody looks at you. The man in the hat smiles
and says:

"Welcome, you can stay as long as you want but you can never leave" 
                   
What do they mean by that? Dusk settles in quickly and the last few
rays of sunlight go with it. You feel lighter.
            """)
     input(prompt = "< Press Any Key to Stay in Purgatory >")
     fail()

def courtyard_lighter():
    print("""
You see a beautiful person dancing in the courtyard with two margaritas in their
hand, they have a very familiar face... 
          
You also see a man with a hat standing next to an unlit candlestick. A bit further, through 
the hallway you can see a car in the parking lot, you have a feeling that it is your car""")
    
    ans = input(prompt = """
 1. Approach the person in the courtyard
 2. Light the Candlestick
 3. Try to leave to the parking lot
 """).lower()
 
    if ans in one:
         dance()
         
    elif ans in two:
        candlestick()
    elif ans in three:
        escape_parking()
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
        print("I didn't catch that")
        courtyard_lighter()
         

def candlestick():
    print(f"""
          
You use your trusty lighter to light the candlestick, the man with the hat looks at
you in the eyes and sends a shiver down your spine
          
"Thank you for lighting that, I could barely see my dice. Say {name}
would you be interested in a gamble with the devil? This is the purgatory {name}
and there is only one way out of here is through me. 
          
Even though you don't remember I know why you are here, it's a sad lonely life 
without your partner. Lucky for you they are here, dancing in the courtyard
          
A simple gamble my friend, first one to reach {max_gamble} with a 6 sided dice wins, 
you may leave with them to live your life and die of old age...
or you can go find them in the courtyard and stay here forever, forever dead"  """)
        
        
    candlestick_2()
    
def candlestick_2():

    ans = input(prompt="""
1. Gamble for your life
2. Stay here 
""").lower()

    if ans in one:
        print("Let's play")
        gamble()
    elif ans in two:
        dance()
        input(prompt = " Press Any Key to Drink Margaritas and Stay in Purgatory")
        fail()
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
        print("Excuse me, can you repeat that?")
        candlestick_2()
        
        

#Dice throwing simulator for escaping the purgatory with your loved one
def gamble():
    
    #creating two dice, one for you and one for the devil
    roll = random.choice(dice)
    roll2 = random.choice(dice)
    
    #assigning the first roll
    my_dice = roll
    devils_dice= roll2
    
    print(f"You start of with a {my_dice} and the devil has a {devils_dice} \n \n \n")
    
    while my_dice <= max_gamble or devils_dice <= max_gamble:
        
        #the new roll based on the same dice
        roll3 = random.choice(dice)
        roll4 = random.choice(dice)
        
        #printing out the totals + creating variables to show who wins
        my_dice= my_dice + roll3
        devils_dice = devils_dice + roll4
        
        input(prompt = "< Press Any Key to Throw Dice > \n")
    
        print("You got a " + str(roll3) + " and your total is: " + str(my_dice) + "\n")
        print("The devil got a " + str(roll4) + " and his total is: " + str(devils_dice) + "\n")
        
      
        
        if my_dice >= max_gamble and my_dice > devils_dice:
            print("I won, I beat the devil")
            gamble_win()
            break
            
        elif devils_dice >= max_gamble and my_dice < devils_dice:
            print("""It's a shame, you should've left when you had the chance. 
Thanks for the lighting the candlestick, but I am afraid you have to stay""")
                  
            ans= input(prompt = "< Press Any Key to Enter Purgatory >")
            
            if ans in again:
                    fail()
                    break
            elif ans in exit:
                    see_ya()
                    break
            else:     
                    fail()
                    break
            
        elif devils_dice >= max_gamble and my_dice >= max_gamble and devils_dice == my_dice:
            print("""It's a draw, unfortunately for you I can't let you leave on a draw.
You are going to have to stay indefinedtley.
                  
You see the final rays of sunlight touch your face and feel
the life leave your body.""")
                  
            input(prompt = "< Press Any Key to Enter Purgatory >")
            fail()
            
            break
      
def gamble_win():
    print(f"""You head inside to find your partner dancing with two glasses of margaritas.
You take their hand as they drop the glasses and leave to the parking lot. The {car} is open with the keys inside
          
Strange, I thought they were in the suitcase...
          
You turn it on and drive onto the sunset and watch the hotel disappear 
into the horizon""")
    input(prompt= "< Press Any key to Get a Second Chance at Life > \n")
    print("You have beat the devil at his own game and get to escape purgatory with your lifelong partner! Enjoy it!")
    
    win()
    
       

def pills():
    ans = input (prompt = """Should you try the door or call reception for help?
                         
                      
1. Try the door
2. Call reception
""").lower()

      
    if ans in one:
        door_travel()
            
    elif ans in two:
            call_reception()
    elif ans in exit:
            see_ya()
    elif ans in again:
        fail()
    else:
            print("Please select a number")
            pills()


def out_of_door():

    ans = input (prompt = """Should you try the door again or call reception?
                         
                      
1. Try the door again
2. Call reception
""").lower()

      
    if ans in one:
        door_travel()
            
    elif ans in two:
            call_reception()
    elif ans in exit:
            see_ya()
    elif ans in again:
            fail()
    else:
            print("Please select a number")
            pills()
            
def door_travel():
    print("""
You try to push the door again. You raise your hands to push it. 
          
Your hands... they fall right through it...
          """)
          
    input(prompt = " < Press Any Key to Cross Door >")   
      
    print("""
You cross the door...
        
Are you a ghost? What is this place you say to yourself.
          
You head to the end of the hallway and go down to the reception. 
There is music playing loudly and other guests are drinking
and dancing in the courtyard.
          
There is a mysterious man with a hat standing next to an
unlit candlestick.
          
""")
    door_travel_1()

#
def door_travel_1():
    ans = input ( prompt = """ 
1. Let's dance and drink baby
2. Try to head to the parking lot
3. Light the Candlestick
""").lower()

    if ans in one:
        print("""Some dance to remember others dance to forget.
              
You dance until you remember, you remember you died a few
days ago, you remember life has been tough on you
since your partner passed away. 
              
You see them looking at you with two glasses of margaritas
              
You smile, but they cry. 
              
"This is not were I wanted to find you again, you had to leave..." 
              
              """)
        input(prompt = "< Press Any Key to Stay in Purgatory >")
        fail()
        
    elif ans in two:
        print ("""You head for the parking lot. As soon as you take a step forward
the music stops, everybody looks at you. The man in the hat smiles
and says:
                   
                   "Welcome, you can stay as long as you want but you can never leave" 
                   
What do they mean by that? Dusk settles in quickly and the last few
rays of sunlight go with it. You feel lighter, you feel dead...
            """)
        input(prompt = "< Press Any Key to Stay in Purgatory >")
        fail()
        
    elif ans in three:
        print("You don't have anything to light the candlestick")
        door_travel_2()
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
        print("I didn't catch that")
        door_travel_1()

#lighter variation has been tried and this is the followup
def door_travel_2():
        ans = input ( prompt = """ 
1. Let's dance and drink baby
2. Try to head to the parking lot

""").lower()

        if ans in one:
            print("""Some dance to remember others dance to forget.
              
              You dance until you remember, you remember you died a few
              days ago, you remember life has been tough on you
              since your partner passed away. 
              
              You see them looking at you with two glasses of margaritas
              
              You smile, but they cry. 
              
              "This is not were I wanted to find you again, you had to leave..." 
              
              """)
            input(prompt = "< Press Any Key to Stay in Purgatory >")
            fail()
        
        elif ans in two:
            print ("""You head for the parking lot. As soon as you take a step 
forward the music stops, everybody looks at you. The man in the hat smiles and says:
    
    
            "Welcome, you can stay as long as you want but you can never leave" 
                   
What do they mean by that? Dusk settles in quickly and the last few rays of 
sunlight go with it. You feel lighter.
            """)
            input(prompt = "< Press Any Key to Stay in Purgatory >")
            fail()
        
        elif ans in exit:
            see_ya()
        elif ans in again:
            fail()
        else:
                print("I didn't catch that")
                door_travel_1()
                
#initial choices when you search the suitcase
def suitcase():
    print("You now have a car key")
    ans = input(prompt = """
1. Check the window
2. Try the door
3. Call Reception

""").lower()

    if ans in one:
        print(f"""You go check for the window to find an empty parking
lot in the dessert except for a {car}""")
        ans1 = input(prompt = """Should you jump out the window from the third floor? You could get hurt
                     
( Yes / No )
""")
        if ans1 in yes:
                parking_lot_key()
        elif ans1 in no:
                call_reception()
        elif ans1 in exit:
                see_ya()
        elif ans1 in again:
                fail()
        else:
            print("I didnt catch that")
            suitcase()
                
    elif ans in two:
        print("""You try the door, except to find that there is no doorknob.""")
        suitcase_2()
        
    elif ans in three:
        call_reception()
    
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
        print("Excuse me what?")
        suitcase()


#further options once checking door has not worked
def suitcase_2():
    ans = input(prompt = """
1. Check the window
2. Call Reception
""")

    if ans in one:
        print(f"""You go check for the window to find an empty parking
lot in the dessert except for a {car}""")
        ans1 = input(prompt = """Should you jump out the window from the third floor? You could get hurt...
                     
( Yes / No )
""").lower()
        if ans1 in yes:
                parking_lot_key()
        elif ans1 in no:
                call_reception()
        elif ans1 in exit:
                see_ya()
        elif ans in again:
                fail()
                
        else:
            print("I didnt catch that")
            suitcase_2()
                
    elif ans in two:
       call_reception()
        
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
        print("Excuse me what?")
        suitcase_2()

#call reception script / separated for organization purposes
def call_reception():
    print(f"""You call reception and they send someone up to help you. The door 
opens and they escort you down to the lobby. You hear music.
          
One of the chaperones says: "The ball is about to begin {name}", 
you don't want to miss it. 
          
You get to the courtyard and see people dancing and drinking all around. One
of them has a very familiar face, you know them from somewhere... 
          
There is also a man with a hat standing next to an unlit candlestick. You can
see a {car} in the parking lot, which you have a feeling that it is your car.""")
          
    call_reception_2()
 
#choices following up the call to reception
def call_reception_2():
    
    ans = input(prompt = """
1. Head to the dance
2. Head to the parking lot
3. Light the candlestick
""").lower()
    if ans in one:
        dance()
    elif ans in two:
        escape_parking()
    elif ans in three:
        print("You cannot light it, since you don't have a lighter")
        call_reception_3()
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
        print("Please pick a number")
        call_reception_2()
          
def call_reception_3(): 
    ans = input(prompt = """
1. Head to the dance
2. Head to the parking lot

""").lower()
    if ans in one:
        dance()
    elif ans in two:
        escape_parking()
 
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
        print("Please pick a number")
        call_reception_3()

#variation of parking lot without key, where you can reach win()
def parking_lot_key():
    print("""You make it down safely, and don't even feel the fall. You hear
          music coming from the reception and there is a tall figure with a 
          cowboy hat standing next to an unlit candle stick. Should you stay around or leave? """)
    
    input (prompt = "< Press Any Key to Continue >")
    
    ans = input (prompt = """
                 
1. Get in the car and drive off
2. Investigate the music
3. Light the candle stick
""").lower()


    if ans in one:
        print(""""You make it to the car. As you are turning on the engine
you turn around to see all of the hotel guests looking at you.
The man with a hat looks at you with a grin and yells:
                  
"Fine, I will allow it only this one time" 
                  
You drive off into the sunset, as the hotel disappears in the distance
you remember. You were dead, your life long partner died a few weeks ago.,
where could they be?...
            
You remember you Od'd with White Rabbit heroin in Vegas just a few days ago.
            
What was that place?
                  
                  """)
        win()
                  
        input( prompt = """Congratulations, you escape Hotel California but 
                  what other secrets await for you to discover?""")
        fail()
            
    elif ans in two:
        print ("""You head back into the Hotel to investigate the music, as you are
               heading back in the man in the hat stops you.
               
               "You can stay as long as you want, but you can never leave." 
               
               You turn around, and its dusk, the last few rays of sunlight disappear, and
               with that, your car is also gone. """)
               
        input(prompt=" <Press Any Key to Stay in Purgatory >")       
        fail()
        
    elif ans in three:
        print("You cannot light the candlestick, since you don't have a lighter")
        parking_lot_key_2()
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
        print("I didn't quite catch that")
        parking_lot_key()   

#variation of parking lot without key, where you can reach win() + lighter option has already been tried
def parking_lot_key_2():
    ans = input (prompt = """
                 
1. Get in the car and drive off
2. Investigate the music""").lower()


    if ans in one:
        print(""""You make it to the car. As you are turning on the engine
              you turn around to see all of the hotel guests looking at you.
              The man with a hat looks at you with a grin and yells:
                  
            "fine, I will allow it only this one time" 
                  
            You drive off into the sunset, as the hotel disappears in the distance
            you remember. You were dead, you Od'd with White Rabbit heroin.
            
            What was that place?
                  
                  """)
                  
     
        win()
            
    elif ans in two:
        print ("""You head back into the Hotel to investigate the music, as you are
               heading back in the man in the hat stops you.
               
               "You can stay as long as you want, but you can never leave." 
               
               You turn around, and its dusk, the last few rays of sunlight disappear, and
               with that, your car is also gone. """)
               
        input(prompt=" <Press Any Key to Stay in Purgatory >")       
        fail()
        
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
        
    else:
        print("I didn't quite catch that")
        parking_lot_key()   


#one final goodbye + invite the user for a last song with webbrowser package
def see_ya():
    music = input(prompt= """
It's a shame to see you go.
Would you like one more song for the road

(Yes / No) ?
""").casefold()

    if music in yes:
         webbrowser.open('https://www.youtube.com/watch?v=vcmjDPDOk7c&ab_channel=IntoMusic')
    elif music in no:
         print("See ya later mate")
    elif music in exit:
        print("See ya later mate")
    elif music in again:
        print("You already chose to leave, no point in turning back now")
    else:
        print("Just put a simple yes or no, I don't have all day")
        see_ya()
    
#standard fail function to let the user know they did not win. 

#the "fail" function also allows the user to restart the 
#game in a yes/no question format

def fail():
    ans = input(prompt = """
You have not been able to escape this time, there is more to uncover...         
                
Would you like to try it again, and again and again?

( Yes / No )
""").casefold()

    if ans in yes:
        part_1()
    elif ans in no:
        see_ya()
    elif ans in exit:
        see_ya()
    elif ans in again:
        fail()
    else:
        print("I didn't quite catch that")
        fail()

#Win function to reward the user when they manage to escape, same as fail but more encouraging.
def win():
    escape = pyfiglet.figlet_format("You escape!", font = "bulbhead" ) 
    print( Fore.BLACK + escape ) 
    print( Style.RESET_ALL)
    
    time.sleep(1)
    
    ans = input(prompt = """
Congratulations, you escape Hotel California but 
what other secrets await for you to discover?      
                
Would you like to try it again, and again and again?

( Yes / No )
""").casefold()

    if ans in yes:
        part_1()
    elif ans in no:
        see_ya()
    elif ans in exit:
        see_ya()
    else:
        print("I didn't quite catch that")
        fail()
        
#let's start this gameeeeee. Best of luck old timer
intro()
# Out:
#              ____  ___   ___    __    ____  ____    ____  _   _  ____
#             ( ___)/ __) / __)  /__\  (  _ \( ___)  (_  _)( )_( )( ___)
#              )__) \__ \( (__  /(__)\  )___/ )__)     )(   ) _ (  )__)
#             (____)(___/ \___)(__)(__)(__)  (____)   (__) (_) (_)(____)
#
#                ___           ___           ___           ___           ___
#               /\__\         /\  \         /\  \         /\  \         /\__\
#              /:/  /        /::\  \        \:\  \       /::\  \       /:/  /
#             /:/__/        /:/\:\  \        \:\  \     /:/\:\  \     /:/  /
#            /::\  \ ___   /:/  \:\  \       /::\  \   /::\~\:\  \   /:/  /
#           /:/\:\  /\__\ /:/__/ \:\__\     /:/\:\__\ /:/\:\ \:\__\ /:/__/
#           \/__\:\/:/  / \:\  \ /:/  /    /:/  \/__/ \:\~\:\ \/__/ \:\  \
#                \::/  /   \:\  /:/  /    /:/  /       \:\ \:\__\    \:\  \
#                /:/  /     \:\/:/  /     \/__/         \:\ \/__/     \:\  \
# ...
